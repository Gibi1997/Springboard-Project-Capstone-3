# %% [markdown]
# DATA WRANGLING

# %%
#Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import Counter

# !pip install wordcloud
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer

# !pip install detoxify
from detoxify import Detoxify
import pandas as pd
from tqdm import tqdm
# Out:
# Requirement already satisfied: wordcloud in c:\users\gibib\anaconda3\lib\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\gibib\anaconda3\lib\site-packages (from wordcloud) (2.1.3)
# Requirement already satisfied: pillow in c:\users\gibib\anaconda3\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\gibib\anaconda3\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gibib\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gibib\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gibib\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gibib\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\gibib\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gibib\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gibib\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\gibib\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Requirement already satisfied: detoxify in c:\users\gibib\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: transformers in c:\users\gibib\anaconda3\lib\site-packages (from detoxify) (5.2.0)
# Requirement already satisfied: torch>=1.7.0 in c:\users\gibib\anaconda3\lib\site-packages (from detoxify) (2.10.0)
# Requirement already satisfied: sentencepiece>=0.1.94 in c:\users\gibib\anaconda3\lib\site-packages (from detoxify) (0.2.1)
# Requirement already satisfied: filelock in c:\users\gibib\anaconda3\lib\site-packages (from torch>=1.7.0->detoxify) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\gibib\anaconda3\lib\site-packages (from torch>=1.7.0->detoxify) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\gibib\anaconda3\lib\site-packages (from torch>=1.7.0->detoxify) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\gibib\anaconda3\lib\site-packages (from torch>=1.7.0->detoxify) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\gibib\anaconda3\lib\site-packages (from torch>=1.7.0->detoxify) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\gibib\anaconda3\lib\site-packages (from torch>=1.7.0->detoxify) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\gibib\anaconda3\lib\site-packages (from torch>=1.7.0->detoxify) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\gibib\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.7.0->detoxify) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gibib\anaconda3\lib\site-packages (from jinja2->torch>=1.7.0->detoxify) (3.0.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in c:\users\gibib\anaconda3\lib\site-packages (from transformers->detoxify) (1.5.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\gibib\anaconda3\lib\site-packages (from transformers->detoxify) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\gibib\anaconda3\lib\site-packages (from transformers->detoxify) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\gibib\anaconda3\lib\site-packages (from transformers->detoxify) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\gibib\anaconda3\lib\site-packages (from transformers->detoxify) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\gibib\anaconda3\lib\site-packages (from transformers->detoxify) (0.22.2)
# Requirement already satisfied: typer-slim in c:\users\gibib\anaconda3\lib\site-packages (from transformers->detoxify) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\gibib\anaconda3\lib\site-packages (from transformers->detoxify) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\gibib\anaconda3\lib\site-packages (from transformers->detoxify) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\gibib\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (1.3.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\gibib\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (0.28.1)
# Requirement already satisfied: typer in c:\users\gibib\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (0.24.1)
# Requirement already satisfied: anyio in c:\users\gibib\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (4.7.0)
# Requirement already satisfied: certifi in c:\users\gibib\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\gibib\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (1.0.9)
# Requirement already satisfied: idna in c:\users\gibib\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\gibib\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (0.16.0)
# Requirement already satisfied: colorama in c:\users\gibib\anaconda3\lib\site-packages (from tqdm>=4.27->transformers->detoxify) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\gibib\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in c:\users\gibib\anaconda3\lib\site-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\gibib\anaconda3\lib\site-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (1.5.0)
# Requirement already satisfied: rich>=12.3.0 in c:\users\gibib\anaconda3\lib\site-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\gibib\anaconda3\lib\site-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\gibib\anaconda3\lib\site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gibib\anaconda3\lib\site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gibib\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers->detoxify) (0.1.0)

# %%
#One of the supplied CSV data file is the raw_data directory
true_news=pd.read_csv(r'C:\Users\gibib\Desktop\Data Scientist\Springboard-Project-Capstone-3\News_dataset/True.csv')

# %%
true_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  object
#  1   text     21417 non-null  object
#  2   subject  21417 non-null  object
#  3   date     21417 non-null  object
# dtypes: object(4)
# memory usage: 669.4+ KB

# %%
true_news.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
# Other supplied CSV data file is the raw_data directory.
fake_news=pd.read_csv(r'C:\Users\gibib\Desktop\Data Scientist\Springboard-Project-Capstone-3\News_dataset/Fake.csv')

# %%
fake_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB

# %%
fake_news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
#Adding a column 'status' to true_news with all values as 'True'
true_news['status'] = 'True'

# %%
true_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  object
#  1   text     21417 non-null  object
#  2   subject  21417 non-null  object
#  3   date     21417 non-null  object
#  4   status   21417 non-null  object
# dtypes: object(5)
# memory usage: 836.7+ KB

# %%
true_news.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date status
# 0  December 31, 2017    True
# 1  December 29, 2017    True
# 2  December 31, 2017    True
# 3  December 30, 2017    True
# 4  December 29, 2017    True

# %%
#Adding a column 'status' to fake_news with all values as 'Fake'
fake_news['status'] = 'Fake'

# %%
fake_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
#  4   status   23481 non-null  object
# dtypes: object(5)
# memory usage: 917.4+ KB

# %%
fake_news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date status
# 0  December 31, 2017   Fake
# 1  December 31, 2017   Fake
# 2  December 30, 2017   Fake
# 3  December 29, 2017   Fake
# 4  December 25, 2017   Fake

# %%
#Combining both the dataframes true_news and fake_news as a new dataframe df_news
df_news = pd.concat([true_news, fake_news], ignore_index=True)

# %%
df_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   status   44898 non-null  object
# dtypes: object(5)
# memory usage: 1.7+ MB

# %%
df_news.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date status
# 0  December 31, 2017    True
# 1  December 29, 2017    True
# 2  December 31, 2017    True
# 3  December 30, 2017    True
# 4  December 29, 2017    True

# %%
df_news.shape
# Out:
# (44898, 5)

# %%
#Shuffling the data, otherwise  all True news comes first, then all Fake news.
df_news = df_news.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df_news.head()
# Out:
#                                                title  \
# 0   BREAKING: GOP Chairman Grassley Has Had Enoug...
# 1   Failed GOP Candidates Remembered In Hilarious...
# 2   Mike Pence’s New DC Neighbors Are HILARIOUSLY...
# 3  California AG pledges to defend birth control ...
# 4  AZ RANCHERS Living On US-Mexico Border Destroy...
#
#                                                 text       subject  \
# 0  Donald Trump s White House is in chaos, and th...          News
# 1  Now that Donald Trump is the presumptive GOP n...          News
# 2  Mike Pence is a huge homophobe. He supports ex...          News
# 3  SAN FRANCISCO (Reuters) - California Attorney ...  politicsNews
# 4  Twisted reasoning is all that comes from Pelos...      politics
#
#                date status
# 0     July 21, 2017   Fake
# 1       May 7, 2016   Fake
# 2  December 3, 2016   Fake
# 3  October 6, 2017    True
# 4      Apr 25, 2017   Fake

# %%
#Converting status column 'True'to 1, 'Fake'to 0
df_news['status'] = df_news['status'].map({'True': 1, 'Fake': 0})

# %%
#Combining title and text to create a new column content.
df_news['content'] = df_news['title'] + " " + df_news['text']

# %%
df_news.head()
# Out:
#                                                title  \
# 0   BREAKING: GOP Chairman Grassley Has Had Enoug...
# 1   Failed GOP Candidates Remembered In Hilarious...
# 2   Mike Pence’s New DC Neighbors Are HILARIOUSLY...
# 3  California AG pledges to defend birth control ...
# 4  AZ RANCHERS Living On US-Mexico Border Destroy...
#
#                                                 text       subject  \
# 0  Donald Trump s White House is in chaos, and th...          News
# 1  Now that Donald Trump is the presumptive GOP n...          News
# 2  Mike Pence is a huge homophobe. He supports ex...          News
# 3  SAN FRANCISCO (Reuters) - California Attorney ...  politicsNews
# 4  Twisted reasoning is all that comes from Pelos...      politics
#
#                date  status                                            content
# 0     July 21, 2017       0   BREAKING: GOP Chairman Grassley Has Had Enoug...
# 1       May 7, 2016       0   Failed GOP Candidates Remembered In Hilarious...
# 2  December 3, 2016       0   Mike Pence’s New DC Neighbors Are HILARIOUSLY...
# 3  October 6, 2017        1  California AG pledges to defend birth control ...
# 4      Apr 25, 2017       0  AZ RANCHERS Living On US-Mexico Border Destroy...

# %%
#Check missing values
df_news.isna().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# status     0
# content    0
# dtype: int64

# %% [markdown]
# No missing values found.

# %%
#Checking duplicates values
df_news.duplicated().sum()
# Out:
# np.int64(209)

# %%
#Removing duplicate values
df_news = df_news.drop_duplicates()

# %%
#Confirming no duplicates values 
df_news.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44689 entries, 0 to 44897
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44689 non-null  object
#  1   text     44689 non-null  object
#  2   subject  44689 non-null  object
#  3   date     44689 non-null  object
#  4   status   44689 non-null  int64
#  5   content  44689 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 2.4+ MB

# %%
#Making the date column consistent and converting the data type to datetime.
# Step 1: Strip leading/trailing spaces from the date column
df_news['date'] = df_news['date'].astype(str).str.strip()

# Step 2: Try parsing dates to see which entries are invalid (would become NaT)
# This does NOT overwrite your column yet
parsed_dates = pd.to_datetime(df_news['date'], format='mixed', errors='coerce')

# Step 3: Display the invalid dates along with their 'status' column
invalid_rows = df_news[parsed_dates.isna()][['date', 'status']]
print("Invalid dates with status:")
print(invalid_rows)

# Step 4: Convert the entire date column to datetime
# Valid dates become datetime64[ns], invalid dates become NaT
df_news['date'] = pd.to_datetime(df_news['date'], format='mixed', errors='coerce')
# Out:
# Invalid dates with status:
#                                                     date  status
# 13550  https://100percentfedup.com/12-yr-old-black-co...       0
# 16730  https://fedup.wpengine.com/wp-content/uploads/...       0
# 18327  https://fedup.wpengine.com/wp-content/uploads/...       0
# 18825  https://100percentfedup.com/video-hillary-aske...       0
# 20827  MSNBC HOST Rudely Assumes Steel Worker Would N...       0
# 22439  https://fedup.wpengine.com/wp-content/uploads/...       0
# 26511  https://100percentfedup.com/served-roy-moore-v...       0
# 32368  https://fedup.wpengine.com/wp-content/uploads/...       0
# 43173  https://fedup.wpengine.com/wp-content/uploads/...       0
# 44358  https://fedup.wpengine.com/wp-content/uploads/...       0

# %% [markdown]
# We can see that all invalid dates belong to fake articles. Since they’re fake news, the missing dates don’t represent critical “real” events. So we can safely replace the null dates with a placeholder. Since most of the dates are from 2016 and 2017, the placeholder date selected is 2017-01-01.

# %%
#Replace NaT with placeholder date
df_news['date'].fillna(pd.Timestamp("2017-01-01"), inplace=True)
# Out:
# C:\Users\gibib\AppData\Local\Temp\ipykernel_5284\2539477764.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_news['date'].fillna(pd.Timestamp("2017-01-01"), inplace=True)

# %%
#Confirming no null values
print(df_news['date'].isna().sum())
# Out:
# 0

# %%
df_news.head(20)
# Out:
#                                                 title  \
# 0    BREAKING: GOP Chairman Grassley Has Had Enoug...
# 1    Failed GOP Candidates Remembered In Hilarious...
# 2    Mike Pence’s New DC Neighbors Are HILARIOUSLY...
# 3   California AG pledges to defend birth control ...
# 4   AZ RANCHERS Living On US-Mexico Border Destroy...
# 5   As private lawyer, Trump high court pick was f...
# 6        Yemeni Salafist imam killed in Aden: sources
# 7   FBI says witnesses in U.S. probe into Malaysia...
# 8   An Easy To Read Chart Shows How Bernie Sanders...
# 9   MMA FIGHTER JAKE SHIELDS Embarrasses Cowards I...
# 10   Tired Of Things Going Well, Marco Rubio Makes...
# 11  Yemen air strike kills eight women, two childr...
# 12  BREAKING: WDBJ KILLER WAS ANGRY BLACK DEMOCRAT...
# 13  LIST OF 22 TIMES OBAMA Called Phony Climate Ch...
# 14   Indo-Pacific? Not from where China is sitting...
# 15  ART CONTEST WINNER Disqualified for Being a Tr...
# 16  'Lips and teeth' no more as China's ties with ...
# 17  Factbox: Trump on Twitter (Sept 25) - NASCAR, ...
# 18  Judge declines to dismiss bribery charges agai...
# 19  FATHER OF BENGHAZI VICTIM TY WOODS SPEAKS UP A...
#
#                                                  text       subject  \
# 0   Donald Trump s White House is in chaos, and th...          News
# 1   Now that Donald Trump is the presumptive GOP n...          News
# 2   Mike Pence is a huge homophobe. He supports ex...          News
# 3   SAN FRANCISCO (Reuters) - California Attorney ...  politicsNews
# 4   Twisted reasoning is all that comes from Pelos...      politics
# 5   WASHINGTON (Reuters) - As a lawyer in private ...  politicsNews
# 6   ADEN (Reuters) - A Salafist imam was shot dead...     worldnews
# 7   KUALA LUMPUR (Reuters) - Potential witnesses t...     worldnews
# 8    The goal of socialism is communism.  -Vladimi...      politics
# 9   Opposing views and beliefs has much of this co...      politics
# 10  Listening to several of the Republican candida...          News
# 11  DUBAI (Reuters) - Eight women and two children...     worldnews
# 12  An angry black, gay, racist, Democrat victim t...      politics
# 13  Oh the irony of a terror attack by Muslims tak...      politics
# 14  BEIJING/NEW DELHI (Reuters) - As U.S. Presiden...     worldnews
# 15  So now if you enter a contest, you need to wor...      politics
# 16  BEIJING (Reuters) - When Kim Jong Un inherited...     worldnews
# 17  The following statements were posted to the ve...  politicsNews
# 18  NEWARK, N.J. (Reuters) - The bribery case agai...  politicsNews
# 19                                                         politics
#
#          date  status                                            content
# 0  2017-07-21       0   BREAKING: GOP Chairman Grassley Has Had Enoug...
# 1  2016-05-07       0   Failed GOP Candidates Remembered In Hilarious...
# 2  2016-12-03       0   Mike Pence’s New DC Neighbors Are HILARIOUSLY...
# 3  2017-10-06       1  California AG pledges to defend birth control ...
# 4  2017-04-25       0  AZ RANCHERS Living On US-Mexico Border Destroy...
# 5  2017-02-01       1  As private lawyer, Trump high court pick was f...
# 6  2017-10-28       1  Yemeni Salafist imam killed in Aden: sources A...
# 7  2017-09-06       1  FBI says witnesses in U.S. probe into Malaysia...
# 8  2016-02-24       0  An Easy To Read Chart Shows How Bernie Sanders...
# 9  2017-02-04       0  MMA FIGHTER JAKE SHIELDS Embarrasses Cowards I...
# 10 2016-01-01       0   Tired Of Things Going Well, Marco Rubio Makes...
# 11 2017-12-18       1  Yemen air strike kills eight women, two childr...
# 12 2015-08-26       0  BREAKING: WDBJ KILLER WAS ANGRY BLACK DEMOCRAT...
# 13 2015-12-03       0  LIST OF 22 TIMES OBAMA Called Phony Climate Ch...
# 14 2017-11-10       1  Indo-Pacific? Not from where China is sitting....
# 15 2017-07-23       0  ART CONTEST WINNER Disqualified for Being a Tr...
# 16 2017-09-08       1  'Lips and teeth' no more as China's ties with ...
# 17 2017-09-26       1  Factbox: Trump on Twitter (Sept 25) - NASCAR, ...
# 18 2017-10-16       1  Judge declines to dismiss bribery charges agai...
# 19 2016-09-10       0  FATHER OF BENGHAZI VICTIM TY WOODS SPEAKS UP A...

# %%
#Checking data types
df_news.dtypes
# Out:
# title              object
# text               object
# subject            object
# date       datetime64[ns]
# status              int64
# content            object
# dtype: object

# %%
df_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44689 entries, 0 to 44897
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44689 non-null  object
#  1   text     44689 non-null  object
#  2   subject  44689 non-null  object
#  3   date     44689 non-null  datetime64[ns]
#  4   status   44689 non-null  int64
#  5   content  44689 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 2.4+ MB

# %%
#Checking consistency
df_news['status'].value_counts()
# Out:
# status
# 0    23478
# 1    21211
# Name: count, dtype: int64

# %%
#Checking consistency
df_news['subject'].value_counts()
# Out:
# subject
# politicsNews       11220
# worldnews           9991
# News                9050
# politics            6838
# left-news           4459
# Government News     1570
# US_News              783
# Middle-east          778
# Name: count, dtype: int64

# %%
#Checking for outliers and removing them
# Compute text length (number of words in content)
df_news['content_length'] = df_news['content'].str.split().apply(len)

# Quick stats
print(df_news['content_length'].describe())

#Plotting histogram
df_news['content_length'].hist(bins=50)
plt.xlabel('Number of words')
plt.ylabel('Number of articles')
plt.show()

# Identify very short articles (< 5 words)
short_articles = df_news[df_news['content_length'] < 5]
print(f"Number of very short articles: {len(short_articles)}")

# Identify very long articles (e.g., > 2 standard deviations above mean)
mean_len = df_news['content_length'].mean()
std_len = df_news['content_length'].std()
long_threshold = mean_len + 2*std_len
long_articles = df_news[df_news['content_length'] > long_threshold]
print(f"Number of very long articles: {len(long_articles)}")

# Filter out extreme outliers
df_news_clean = df_news[(df_news['content_length'] >= 5) & (df_news['content_length'] <= long_threshold)]

# Reset index
df_news_clean = df_news_clean.reset_index(drop=True)

print(f"Dataset size after removing outliers: {df_news_clean.shape[0]}")
# Out:
# count    44689.000000
# mean       417.429748
# std        351.792113
# min          2.000000
# 25%        215.000000
# 50%        374.000000
# 75%        525.000000
# max       8148.000000
# Name: content_length, dtype: float64
# Number of very short articles: 11
# Number of very long articles: 1122
# Dataset size after removing outliers: 43556

# %%
df_news_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43556 entries, 0 to 43555
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           43556 non-null  object
#  1   text            43556 non-null  object
#  2   subject         43556 non-null  object
#  3   date            43556 non-null  datetime64[ns]
#  4   status          43556 non-null  int64
#  5   content         43556 non-null  object
#  6   content_length  43556 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 2.3+ MB

# %%
df_news_clean.head()
# Out:
#                                                title  \
# 0   BREAKING: GOP Chairman Grassley Has Had Enoug...
# 1   Failed GOP Candidates Remembered In Hilarious...
# 2   Mike Pence’s New DC Neighbors Are HILARIOUSLY...
# 3  California AG pledges to defend birth control ...
# 4  AZ RANCHERS Living On US-Mexico Border Destroy...
#
#                                                 text       subject       date  \
# 0  Donald Trump s White House is in chaos, and th...          News 2017-07-21
# 1  Now that Donald Trump is the presumptive GOP n...          News 2016-05-07
# 2  Mike Pence is a huge homophobe. He supports ex...          News 2016-12-03
# 3  SAN FRANCISCO (Reuters) - California Attorney ...  politicsNews 2017-10-06
# 4  Twisted reasoning is all that comes from Pelos...      politics 2017-04-25
#
#    status                                            content  content_length
# 0       0   BREAKING: GOP Chairman Grassley Has Had Enoug...             372
# 1       0   Failed GOP Candidates Remembered In Hilarious...             504
# 2       0   Mike Pence’s New DC Neighbors Are HILARIOUSLY...             393
# 3       1  California AG pledges to defend birth control ...              97
# 4       0  AZ RANCHERS Living On US-Mexico Border Destroy...             157

# %%
# Clean text: lowercase, remove non-letters & stopwords, ready for NLP
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    words = text.split()
    words = [word for word in words if word not in stop_words]
    return " ".join(words)

df_news_clean['content'] = df_news_clean['content'].apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gibib\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Tokenization – splitting text into individual words/tokens
df_news_clean['tokens'] = df_news_clean['content'].apply(lambda x: x.split())

# %%
df_news_clean.head()
# Out:
#                                                title  \
# 0   BREAKING: GOP Chairman Grassley Has Had Enoug...
# 1   Failed GOP Candidates Remembered In Hilarious...
# 2   Mike Pence’s New DC Neighbors Are HILARIOUSLY...
# 3  California AG pledges to defend birth control ...
# 4  AZ RANCHERS Living On US-Mexico Border Destroy...
#
#                                                 text       subject       date  \
# 0  Donald Trump s White House is in chaos, and th...          News 2017-07-21
# 1  Now that Donald Trump is the presumptive GOP n...          News 2016-05-07
# 2  Mike Pence is a huge homophobe. He supports ex...          News 2016-12-03
# 3  SAN FRANCISCO (Reuters) - California Attorney ...  politicsNews 2017-10-06
# 4  Twisted reasoning is all that comes from Pelos...      politics 2017-04-25
#
#    status                                            content  content_length  \
# 0       0  breaking gop chairman grassley enough demands ...             372
# 1       0  failed gop candidates remembered hilarious moc...             504
# 2       0  mike pences new dc neighbors hilariously troll...             393
# 3       1  california ag pledges defend birth control ins...              97
# 4       0  az ranchers living usmexico border destroy nan...             157
#
#                                               tokens
# 0  [breaking, gop, chairman, grassley, enough, de...
# 1  [failed, gop, candidates, remembered, hilariou...
# 2  [mike, pences, new, dc, neighbors, hilariously...
# 3  [california, ag, pledges, defend, birth, contr...
# 4  [az, ranchers, living, usmexico, border, destr...

# %%
#Lemmatization – reducing words to their dictionary/base form
lemmatizer = WordNetLemmatizer()

df_news_clean['lemmatized_tokens'] = df_news_clean['tokens'].apply(
    lambda words: [lemmatizer.lemmatize(word) for word in words]
)

# %%
df_news_clean.head()
# Out:
#                                                title  \
# 0   BREAKING: GOP Chairman Grassley Has Had Enoug...
# 1   Failed GOP Candidates Remembered In Hilarious...
# 2   Mike Pence’s New DC Neighbors Are HILARIOUSLY...
# 3  California AG pledges to defend birth control ...
# 4  AZ RANCHERS Living On US-Mexico Border Destroy...
#
#                                                 text       subject       date  \
# 0  Donald Trump s White House is in chaos, and th...          News 2017-07-21
# 1  Now that Donald Trump is the presumptive GOP n...          News 2016-05-07
# 2  Mike Pence is a huge homophobe. He supports ex...          News 2016-12-03
# 3  SAN FRANCISCO (Reuters) - California Attorney ...  politicsNews 2017-10-06
# 4  Twisted reasoning is all that comes from Pelos...      politics 2017-04-25
#
#    status                                            content  content_length  \
# 0       0  breaking gop chairman grassley enough demands ...             372
# 1       0  failed gop candidates remembered hilarious moc...             504
# 2       0  mike pences new dc neighbors hilariously troll...             393
# 3       1  california ag pledges defend birth control ins...              97
# 4       0  az ranchers living usmexico border destroy nan...             157
#
#                                               tokens  \
# 0  [breaking, gop, chairman, grassley, enough, de...
# 1  [failed, gop, candidates, remembered, hilariou...
# 2  [mike, pences, new, dc, neighbors, hilariously...
# 3  [california, ag, pledges, defend, birth, contr...
# 4  [az, ranchers, living, usmexico, border, destr...
#
#                                    lemmatized_tokens
# 0  [breaking, gop, chairman, grassley, enough, de...
# 1  [failed, gop, candidate, remembered, hilarious...
# 2  [mike, pences, new, dc, neighbor, hilariously,...
# 3  [california, ag, pledge, defend, birth, contro...
# 4  [az, rancher, living, usmexico, border, destro...

# %%
# Convert the list of lemmatized tokens back into a single cleaned text string
df_news_clean['lemmatized_content'] = df_news_clean['lemmatized_tokens'].apply(lambda x: " ".join(x))

# %%
df_news_clean.head()
# Out:
#                                                title  \
# 0   BREAKING: GOP Chairman Grassley Has Had Enoug...
# 1   Failed GOP Candidates Remembered In Hilarious...
# 2   Mike Pence’s New DC Neighbors Are HILARIOUSLY...
# 3  California AG pledges to defend birth control ...
# 4  AZ RANCHERS Living On US-Mexico Border Destroy...
#
#                                                 text       subject       date  \
# 0  Donald Trump s White House is in chaos, and th...          News 2017-07-21
# 1  Now that Donald Trump is the presumptive GOP n...          News 2016-05-07
# 2  Mike Pence is a huge homophobe. He supports ex...          News 2016-12-03
# 3  SAN FRANCISCO (Reuters) - California Attorney ...  politicsNews 2017-10-06
# 4  Twisted reasoning is all that comes from Pelos...      politics 2017-04-25
#
#    status                                            content  content_length  \
# 0       0  breaking gop chairman grassley enough demands ...             372
# 1       0  failed gop candidates remembered hilarious moc...             504
# 2       0  mike pences new dc neighbors hilariously troll...             393
# 3       1  california ag pledges defend birth control ins...              97
# 4       0  az ranchers living usmexico border destroy nan...             157
#
#                                               tokens  \
# 0  [breaking, gop, chairman, grassley, enough, de...
# 1  [failed, gop, candidates, remembered, hilariou...
# 2  [mike, pences, new, dc, neighbors, hilariously...
# 3  [california, ag, pledges, defend, birth, contr...
# 4  [az, ranchers, living, usmexico, border, destr...
#
#                                    lemmatized_tokens  \
# 0  [breaking, gop, chairman, grassley, enough, de...
# 1  [failed, gop, candidate, remembered, hilarious...
# 2  [mike, pences, new, dc, neighbor, hilariously,...
# 3  [california, ag, pledge, defend, birth, contro...
# 4  [az, rancher, living, usmexico, border, destro...
#
#                                   lemmatized_content
# 0  breaking gop chairman grassley enough demand t...
# 1  failed gop candidate remembered hilarious mock...
# 2  mike pences new dc neighbor hilariously trolli...
# 3  california ag pledge defend birth control insu...
# 4  az rancher living usmexico border destroy nanc...

# %%
#Frequency Analysis – find the most common words(in fake and true news) in the dataset
#Separate words by class
fake_words = [word for tokens in df_news_clean[df_news_clean['status']==0]['lemmatized_tokens'] for word in tokens]
true_words = [word for tokens in df_news_clean[df_news_clean['status']==1]['lemmatized_tokens'] for word in tokens]

# Count frequency
fake_freq = Counter(fake_words)
true_freq = Counter(true_words)

print("Most common words in fake news:\n")
print(fake_freq.most_common(20))

print("\nMost common words in true news:\n")
print(true_freq.most_common(20))
# Out:
# Most common words in fake news:
#
# [('trump', 78082), ('said', 27765), ('president', 24267), ('people', 23449), ('one', 20595), ('would', 20236), ('state', 18656), ('u', 17955), ('obama', 17599), ('donald', 17011), ('clinton', 16353), ('video', 16223), ('like', 16217), ('republican', 15836), ('time', 15255), ('say', 14435), ('american', 14147), ('hillary', 13876), ('image', 13628), ('year', 12778)]
#
# Most common words in true news:
#
# [('said', 94579), ('trump', 56356), ('u', 43009), ('state', 35201), ('would', 30205), ('reuters', 27278), ('president', 26248), ('republican', 22067), ('government', 18894), ('year', 18341), ('house', 17530), ('new', 16909), ('also', 15162), ('united', 14803), ('party', 14695), ('people', 14526), ('official', 14153), ('election', 13814), ('told', 13585), ('country', 13344)]

# %% [markdown]
# Notable fake-heavy words:
# obama,
# clinton,
# hillary,
# video,
# image,
# like,
# donald.
#
# Fake news often:
# Uses more personal names,
# Refers to media elements (video, image),
# Uses more opinion/emotion-based language.
#
# Notable true-heavy words:
# reuters,
# government,
# official,
# united,
# party,
# election,
# country,
# told.
#
# True news:
# Uses institutional language,
# Mentions official sources,
# More formal journalistic structure.

# %% [markdown]
# Next step applies the Detoxify deep learning model to measure the level of toxic language present in each news article. Instead of analyzing the entire article, only the first 500 characters are used to reduce computational time while still capturing most linguistic signals. The dataset is processed in batches of 64 articles to improve efficiency and avoid memory issues. For each article, Detoxify generates six toxicity-related scores: toxicity, severe toxicity, obscene, threat, insult, and identity attack. These scores are then appended to the dataset as new numerical features, which can be analyzed during Exploratory Data Analysis (EDA) and potentially used as additional predictors in the fake news classification model.

# %%
# Load Detoxify model (pretrained toxicity detection model)
model = Detoxify('original')

# Use only the first 1500 characters of each article
# This speeds up prediction because toxicity signals usually appear early in the text
texts = df_news_clean['content'].str[:500].tolist()

# Set batch size (number of articles processed at once)
batch_size = 64

# List to store toxicity predictions
results = []

# Process the dataset in batches
for i in tqdm(range(0, len(texts), batch_size)):
    
    # Select a batch of articles
    batch = texts[i:i+batch_size]
    
    # Predict toxicity scores for the batch
    preds = model.predict(batch)
    
    # Convert predictions to dataframe
    results.append(pd.DataFrame(preds))

# Combine all batch results into a single dataframe
toxicity_df = pd.concat(results).reset_index(drop=True)

# Merge toxicity scores with the original dataset
df_news_clean = pd.concat([df_news_clean.reset_index(drop=True), toxicity_df], axis=1)

# Display confirmation
print("Toxicity features added successfully!")

# View first rows
df_news_clean.head()
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: None
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 100%|██████████████████████████████████████████████████████████████████████████████| 681/681 [1:49:33<00:00,  9.65s/it]
# Toxicity features added successfully!
#                                                title  \
# 0   BREAKING: GOP Chairman Grassley Has Had Enoug...
# 1   Failed GOP Candidates Remembered In Hilarious...
# 2   Mike Pence’s New DC Neighbors Are HILARIOUSLY...
# 3  California AG pledges to defend birth control ...
# 4  AZ RANCHERS Living On US-Mexico Border Destroy...
#
#                                                 text       subject       date  \
# 0  Donald Trump s White House is in chaos, and th...          News 2017-07-21
# 1  Now that Donald Trump is the presumptive GOP n...          News 2016-05-07
# 2  Mike Pence is a huge homophobe. He supports ex...          News 2016-12-03
# 3  SAN FRANCISCO (Reuters) - California Attorney ...  politicsNews 2017-10-06
# 4  Twisted reasoning is all that comes from Pelos...      politics 2017-04-25
#
#    status                                            content  content_length  \
# 0       0  breaking gop chairman grassley enough demands ...             372
# 1       0  failed gop candidates remembered hilarious moc...             504
# 2       0  mike pences new dc neighbors hilariously troll...             393
# 3       1  california ag pledges defend birth control ins...              97
# 4       0  az ranchers living usmexico border destroy nan...             157
#
#                                               tokens  \
# 0  [breaking, gop, chairman, grassley, enough, de...
# 1  [failed, gop, candidates, remembered, hilariou...
# 2  [mike, pences, new, dc, neighbors, hilariously...
# 3  [california, ag, pledges, defend, birth, contr...
# 4  [az, ranchers, living, usmexico, border, destr...
#
#                                    lemmatized_tokens  \
# 0  [breaking, gop, chairman, grassley, enough, de...
# 1  [failed, gop, candidate, remembered, hilarious...
# 2  [mike, pences, new, dc, neighbor, hilariously,...
# 3  [california, ag, pledge, defend, birth, contro...
# 4  [az, rancher, living, usmexico, border, destro...
#
#                                   lemmatized_content  toxicity  \
# 0  breaking gop chairman grassley enough demand t...  0.001761
# 1  failed gop candidate remembered hilarious mock...  0.048552
# 2  mike pences new dc neighbor hilariously trolli...  0.201606
# 3  california ag pledge defend birth control insu...  0.002383
# 4  az rancher living usmexico border destroy nanc...  0.006283
#
#    severe_toxicity   obscene    threat    insult  identity_attack
# 0         0.000095  0.000251  0.000104  0.000191         0.000147
# 1         0.000174  0.003607  0.000220  0.003166         0.000414
# 2         0.000940  0.007158  0.001141  0.008911         0.029199
# 3         0.000094  0.000289  0.000116  0.000207         0.000161
# 4         0.000099  0.000515  0.000148  0.000350         0.000185

# %%
df_news_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43556 entries, 0 to 43555
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               43556 non-null  object
#  1   text                43556 non-null  object
#  2   subject             43556 non-null  object
#  3   date                43556 non-null  datetime64[ns]
#  4   status              43556 non-null  int64
#  5   content             43556 non-null  object
#  6   content_length      43556 non-null  int64
#  7   tokens              43556 non-null  object
#  8   lemmatized_tokens   43556 non-null  object
#  9   lemmatized_content  43556 non-null  object
#  10  toxicity            43556 non-null  float64
#  11  severe_toxicity     43556 non-null  float64
#  12  obscene             43556 non-null  float64
#  13  threat              43556 non-null  float64
#  14  insult              43556 non-null  float64
#  15  identity_attack     43556 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(7)
# memory usage: 5.3+ MB

# %% [markdown]
# SUMMARY:
# The dataset was first created by combining True and Fake news sources, with a new column status added to label True news as 1 and Fake news as 0. There were total 44898 rows and 5 columns for the dataset at first. The title and text columns were combined into a single content column to serve as the main text for analysis. The date column was cleaned. The text data was cleaned by converting all text to lowercase, removing punctuation and special characters, and eliminating common English stopwords. For natural language processing, the text was tokenized into individual words and then lemmatized using WordNet to reduce words to their base forms, resulting in lemmatized_tokens, which were later recombined into lemmatized_content for modeling purposes. Additionally, a numeric feature content_length was created to capture the length of each article. To investigate whether fake news articles exhibit more aggressive or toxic language, toxicity scores were generated using the Detoxify model. Six toxicity-related features were extracted, including toxicity, severe toxicity, obscene language, threats, insults, and identity attacks. The dataset is now fully cleaned, structured, and prepared for exploratory data analysis, frequency analysis and subsequent machine learning modeling, with optional further steps like removing domain-specific high-frequency words for more targeted analysis. After all these cleaning process we have now 43556 rows and 16 columns in the dataframe.

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %% [markdown]
# Since this is an NLP project, EDA will focus on both text features and numerical/statistical insights.

# %%
#Checking the class balance
df_news_clean['status'].value_counts()
# Out:
# status
# 0    22624
# 1    20932
# Name: count, dtype: int64

# %%
df_news_clean['status'].value_counts(normalize=True)  # % distribution
# Out:
# status
# 0    0.519423
# 1    0.480577
# Name: proportion, dtype: float64

# %%
#Plotting the target variable
plt.figure(figsize=(6,4))
sns.countplot(x='status', data=df_news_clean, palette=['red','green'])
plt.xticks([0,1], ['Fake', 'True']) 
plt.title('Distribution of Fake vs True News')
plt.ylabel('Number of Articles')
plt.show()
# Out:
# C:\Users\gibib\AppData\Local\Temp\ipykernel_5284\1368918350.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='status', data=df_news_clean, palette=['red','green'])

# %% [markdown]
# The dataset is slightly imbalanced (~52% Fake vs ~48% True), but it’s not extreme.

# %%
#Summary statistics 
df_news_clean['content_length'].describe()
# Out:
# count    43556.000000
# mean       382.651162
# std        230.220680
# min          6.000000
# 25%        209.000000
# 50%        368.000000
# 75%        509.000000
# max       1121.000000
# Name: content_length, dtype: float64

# %%
#Content length distribution for Fake vs True news.
plt.figure(figsize=(12,6))
sns.histplot(data=df_news_clean, x='content_length', hue='status', bins=50, kde=True, palette=['green','red'], alpha=0.6)
plt.title('Distribution of Article Content Length by News Type')
plt.xlabel('Content Length (No. of words)')
plt.ylabel('Number of Articles')
plt.legend(labels=['Fake','True'])
plt.show()

# %% [markdown]
# Graph shows articles having less no. of words(between 50-200) have more chances to be fake. But otherwise no.of words do not show having influence on fake or true articles.

# %%
#Creating WordClouds to visualize the most frequent words in Fake vs True news.
# Fake news WordCloud
fake_text = " ".join(df_news_clean[df_news_clean['status']==0]['lemmatized_content'])
fake_wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='Reds').generate(fake_text)

plt.figure(figsize=(15,7))
plt.imshow(fake_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Words in Fake News', fontsize=20)
plt.show()

# True news WordCloud
true_text = " ".join(df_news_clean[df_news_clean['status']==1]['lemmatized_content'])
true_wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='Greens').generate(true_text)

plt.figure(figsize=(15,7))
plt.imshow(true_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Words in True News', fontsize=20)
plt.show()

# %% [markdown]
# Fake news: Likely dominated by words like obama, clinton, hillary, video, image, like, donald.
# True news: More formal reporting words like reuters, government, official, united, party, election, country, told.

# %%
#Plotting most common words(in fake and true news) in the dataset
# Fake news top 20
fake_top20 = fake_freq.most_common(20)
words, counts = zip(*fake_top20)

plt.figure(figsize=(12,6))
plt.bar(words, counts, color='red')
plt.xticks(rotation=45)
plt.title('Top 20 Words in Fake News')
plt.ylabel('Frequency')
plt.show()

# True news top 20
true_top20 = true_freq.most_common(20)
words, counts = zip(*true_top20)

plt.figure(figsize=(12,6))
plt.bar(words, counts, color='green')
plt.xticks(rotation=45)
plt.title('Top 20 Words in True News')
plt.ylabel('Frequency')
plt.show()

# %%
#Bigram Analysis to see common word pairs in Fake vs True news
# Function to get top n bigrams for a subset of articles
def get_top_bigrams(df_subset, n=20):
    vectorizer = CountVectorizer(ngram_range=(2,2), stop_words='english')
    X = vectorizer.fit_transform(df_subset['lemmatized_content'])
    bigrams_sum = X.sum(axis=0)
    bigram_freq = [(word, bigrams_sum[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
    bigram_freq = sorted(bigram_freq, key=lambda x: x[1], reverse=True)
    return bigram_freq[:n]

# Top 20 bigrams in Fake news
top_bigrams_fake = get_top_bigrams(df_news_clean[df_news_clean['status']==0])

# Top 20 bigrams in True news
top_bigrams_true = get_top_bigrams(df_news_clean[df_news_clean['status']==1])

# Convert to DataFrame for side-by-side comparison
bigram_comparison = pd.DataFrame({
    'Fake_news_bigrams': [w for w,c in top_bigrams_fake],
    'Fake_count': [c for w,c in top_bigrams_fake],
    'True_news_bigrams': [w for w,c in top_bigrams_true],
    'True_count': [c for w,c in top_bigrams_true]
})

bigram_comparison
# Out:
#         Fake_news_bigrams  Fake_count     True_news_bigrams  True_count
# 0            donald trump       15200          united state       11553
# 1         hillary clinton        6147          donald trump        9908
# 2             white house        5888           white house        8703
# 3            united state        5102    washington reuters        6401
# 4         president trump        3840           north korea        5979
# 5         president obama        3659      president donald        5778
# 6                new york        3455              new york        4386
# 7                fox news        3279        prime minister        4093
# 8         trump supporter        2217        said statement        3855
# 9            barack obama        2027         islamic state        3440
# 10          supreme court        1724         official said        3423
# 11         trump campaign        1720            trump said        3390
# 12  trump realdonaldtrump        1627          told reuters        3243
# 13             st century        1575         told reporter        3092
# 14          bernie sander        1500      president barack        2782
# 15         police officer        1483         supreme court        2593
# 16               ted cruz        1458  trump administration        2462
# 17           century wire        1442       hillary clinton        2446
# 18          social medium        1424          barack obama        2261
# 19              fake news        1405       secretary state        2247

# %% [markdown]
# 1.Fake news bigrams:
#
# Dominated by names, political figures, and sensational phrases:
#
# donald trump, hillary clinton, president trump, fox news, fake news
#
# Shows the tendency of Fake news to focus on people, scandals, and polarizing topics.
#
# 2.True news bigrams:
#
# More formal, reporting-focused phrases:
#
# united state, white house, washington reuters, official said, president donald
#
# Reflects neutral reporting language and source attribution.
#
# 3.Overlap:
#
# Some bigrams appear in both, like donald trump and white house, but their frequency patterns differ:
#
# In Fake news, these bigrams are often more sensational or repeated in viral contexts.
#
# In True news, they are typically part of formal reporting.

# %%
#Trigram Analysis to see common word triplets in Fake vs True news
# Function to get top n trigrams
def get_top_trigrams(df_subset, n=20):
    vectorizer = CountVectorizer(ngram_range=(3,3), stop_words='english')
    X = vectorizer.fit_transform(df_subset['lemmatized_content'])
    trigrams_sum = X.sum(axis=0)
    trigram_freq = [(word, trigrams_sum[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
    trigram_freq = sorted(trigram_freq, key=lambda x: x[1], reverse=True)
    return trigram_freq[:n]

# Top 20 trigrams in Fake news
top_trigrams_fake = get_top_trigrams(df_news_clean[df_news_clean['status']==0])

# Top 20 trigrams in True news
top_trigrams_true = get_top_trigrams(df_news_clean[df_news_clean['status']==1])

# Create DataFrame for side-by-side comparison
trigram_comparison = pd.DataFrame({
    'Fake_news_trigrams': [w for w,c in top_trigrams_fake],
    'Fake_count': [c for w,c in top_trigrams_fake],
    'True_news_trigrams': [w for w,c in top_trigrams_true],
    'True_count': [c for w,c in top_trigrams_true]
})

trigram_comparison
# Out:
#               Fake_news_trigrams  Fake_count  \
# 0   donald trump realdonaldtrump        1625
# 1                st century wire        1426
# 2                  new york time        1148
# 3              black life matter        1142
# 4         president donald trump         904
# 5         president united state         827
# 6         president barack obama         786
# 7           video screen capture         727
# 8             image video screen         696
# 9                news st century         665
# 10              century wire say         633
# 11                 new york city         545
# 12          image screen capture         447
# 13          director james comey         437
# 14            fbi director james         425
# 15            make america great         414
# 16           affordable care act         378
# 17         supreme court justice         360
# 18             white house press         354
# 19            video donald trump         339
#
#                    True_news_trigrams  True_count
# 0              president donald trump        5720
# 1              president barack obama        1906
# 2            reuters president donald        1515
# 3        washington reuters president        1325
# 4                    white house said         946
# 5             president barack obamas         876
# 6         presidentelect donald trump         810
# 7             respond request comment         750
# 8            president vladimir putin         750
# 9                    new york reuters         731
# 10                secretary state rex         651
# 11                state rex tillerson         642
# 12          national security adviser         605
# 13         russian president vladimir         579
# 14                  speaker paul ryan         572
# 15             prime minister theresa         565
# 16                  donald trump said         564
# 17           chancellor angela merkel         550
# 18      washington reuters republican         544
# 19  republican presidential candidate         529

# %% [markdown]
# 1.Fake news trigrams:
#
# Dominated by names, sensational events, and viral sources:
#
# donald trump realdonaldtrump, st century wire, black life matter, video screen capture
#
# Highlights a focus on clickbait, political figures, and media screenshots, typical of Fake news content.
#
# 2.True news trigrams:
#
# Focus on formal reporting, official sources, and political titles:
#
# president donald trump, washington reuters president, white house said, secretary state rex
#
# Reflects neutral, verified, and source-cited reporting, unlike the sensational Fake news trigrams.
#
# 3.Overlap & differences:
#
# Both share names like donald trump and president barack obama, but Fake news adds sensational or viral context (e.g., “realdonaldtrump”, “video screen capture”).
#
# True news often includes official titles and institutional references.

# %%
#Shows which categories dominate Fake or True news.
# Count of each subject by status
subject_status = df_news_clean.groupby(['subject', 'status']).size().unstack(fill_value=0)

# Plot
subject_status.plot(kind='bar', figsize=(12,6), color=['red','green'])
plt.title('News Subject Distribution by Status (Fake vs True)')
plt.xlabel('Subject')
plt.ylabel('Number of Articles')
plt.xticks(rotation=45)
plt.legend(['Fake', 'True'])
plt.show()

# %%
#Creating a table showing subjects and count of both fake and true articles.
# Group by subject and status, count articles
subject_status_table = df_news_clean.groupby(['subject', 'status']).size().unstack(fill_value=0)

# Rename columns for clarity
subject_status_table.columns = ['Fake', 'True']

# Display the table
subject_status_table
# Out:
#                  Fake   True
# subject
# Government News  1500      0
# Middle-east       611      0
# News             9020      0
# US_News           613      0
# left-news        4285      0
# politics         6595      0
# politicsNews        0  11050
# worldnews           0   9882

# %% [markdown]
# This table clearly shows subjects are strongly correlated with status in the dataset. Categories like “politicsNews” and “worldnews” are dominated by True news, while all other categories are mostly fake. Subject is a perfect predictor for Fake vs True news — which means the model might overfit if we include it as a feature; so we have to drop this feature before training.

# %%
#Checking whether toxicity influences the target variable
toxicity_cols = ['toxicity','severe_toxicity','obscene','threat','insult','identity_attack']

corr = df_news_clean[toxicity_cols + ['status']].corr()

print(corr['status'].sort_values(ascending=False))
# Out:
# status             1.000000
# threat            -0.063397
# severe_toxicity   -0.067250
# identity_attack   -0.139634
# insult            -0.156796
# obscene           -0.176365
# toxicity          -0.318570
# Name: status, dtype: float64

# %% [markdown]
# The general toxicity score is the most informative single feature for distinguishing fake news from true news.
#
# Other features like insult, obscene, and identity_attack also carry moderate information, whereas threat and severe_toxicity have very small influence.

# %%
#Compare Means Between Fake vs Real News
df_news_clean.groupby('status')[toxicity_cols].mean()
# Out:
#         toxicity  severe_toxicity   obscene    threat    insult  \
# status
# 0       0.087039         0.001231  0.022429  0.001120  0.013359
# 1       0.005688         0.000130  0.000731  0.000278  0.000384
#
#         identity_attack
# status
# 0              0.009640
# 1              0.000386

# %% [markdown]
# Fake news articles have substantially higher mean toxicity scores across all categories compared to real news.
# Features like threat and severe_toxicity are still higher in fake news but with smaller absolute values.
# This reinforces the correlation analysis: fake news tends to contain more toxic, insulting, or obscene language, making these features informative for classification models.

# %%
# Plotting all 6 toxicity features
# List of toxicity columns
toxicity_cols = ['toxicity','severe_toxicity','obscene','threat','insult','identity_attack']

# Set up the figure grid
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

# Plot each toxicity feature
for i, col in enumerate(toxicity_cols):
    sns.boxplot(
        data=df_news_clean,
        x='status',
        y=col,
        ax=axes[i],
        palette=["#FF6F61","#6B5B95"]
    )
    axes[i].set_title(f"{col.capitalize()} by News Type", fontsize=14)
    axes[i].set_xlabel("News Type (0 = Fake, 1 = Real)")
    axes[i].set_ylabel(col.capitalize())

    # Overlay mean points
    means = df_news_clean.groupby('status')[col].mean().values
    for j, mean in enumerate(means):
        axes[i].scatter(j, mean, color='yellow', s=80, edgecolor='black')

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gibib\AppData\Local\Temp\ipykernel_5284\911358502.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\gibib\AppData\Local\Temp\ipykernel_5284\911358502.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\gibib\AppData\Local\Temp\ipykernel_5284\911358502.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\gibib\AppData\Local\Temp\ipykernel_5284\911358502.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\gibib\AppData\Local\Temp\ipykernel_5284\911358502.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\gibib\AppData\Local\Temp\ipykernel_5284\911358502.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# Overall toxicity, obscene language, insults, and identity attacks are clearly higher in fake news.

# %%
# Save the data to a new csv file
df_news_clean.to_csv(
    r'C:\Users\gibib\Desktop\Data Scientist\Springboard-Project-Capstone-3\News_dataset/Data_cleaned_explored.csv',
    index=False
)

# %% [markdown]
# SUMMARY:
# During EDA, the dataset showed a fairly balanced distribution between Fake (≈52%) and True (≈48%) news. Text characteristics such as content length and token counts indicated that shorter articles are slightly more likely to be fake, though not strongly predictive. Fake news often contained sensational or politically charged terms, while True news used formal reporting words. Toxicity analysis using Detoxify revealed that Fake news consistently exhibits higher levels of aggressive or offensive language across features like toxicity, insult, obscene, and identity_attack. These insights into word usage, categories, and toxicity help differentiate Fake vs True news and inform preprocessing for modeling
